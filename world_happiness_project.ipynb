# %% [markdown]
#                                 WORLD HAPPINESS PROJECT

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
Wh_df=pd.read_csv('happiness_score_data')
Wh_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
#                                  EXPLORATORY DATA ANALYSIS

# %%
new_df=Wh_df.set_index('Country')
new_df
# Out:
#                                       Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland                   Western Europe               1            7.587
# Iceland                       Western Europe               2            7.561
# Denmark                       Western Europe               3            7.527
# Norway                        Western Europe               4            7.522
# Canada                         North America               5            7.427
# ...                                      ...             ...              ...
# Rwanda                    Sub-Saharan Africa             154            3.465
# Benin                     Sub-Saharan Africa             155            3.340
# Syria        Middle East and Northern Africa             156            3.006
# Burundi                   Sub-Saharan Africa             157            2.905
# Togo                      Sub-Saharan Africa             158            2.839
#
# ...

# %%
new_df
# Out:
#                                       Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland                   Western Europe               1            7.587
# Iceland                       Western Europe               2            7.561
# Denmark                       Western Europe               3            7.527
# Norway                        Western Europe               4            7.522
# Canada                         North America               5            7.427
# ...                                      ...             ...              ...
# Rwanda                    Sub-Saharan Africa             154            3.465
# Benin                     Sub-Saharan Africa             155            3.340
# Syria        Middle East and Northern Africa             156            3.006
# Burundi                   Sub-Saharan Africa             157            2.905
# Togo                      Sub-Saharan Africa             158            2.839
#
# ...

# %%
#checking data types of the feature
Wh_df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
sort_df=new_df.groupby('Region').apply(lambda x:x.sort_values(by='Happiness Score',ascending=False))
sort_df.head(10)
top_10_countries=sort_df.head()
print(top_10_countries)
# Out:
#                                                                Region  \
# Region                     Country
# Australia and New Zealand  New Zealand      Australia and New Zealand
#                            Australia        Australia and New Zealand
# Central and Eastern Europe Czech Republic  Central and Eastern Europe
#                            Uzbekistan      Central and Eastern Europe
#                            Slovakia        Central and Eastern Europe
#
#                                            Happiness Rank  Happiness Score  \
# Region                     Country
# Australia and New Zealand  New Zealand                  9            7.286
#                            Australia                   10            7.284
# Central and Eastern Europe Czech Republic              31            6.505
#                            Uzbekistan                  44            6.003
#                            Slovakia                    45            5.995
#
# ...

# %% [markdown]
# here from the above output it is displaying top countries of each region based on their happiness rank

# %%
Wh_df.shape
# Out:
# (158, 12)

# %%
Wh_df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#checking for the null values
Wh_df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# here from the above bservation it is clear that there are no missing values

# %%
Wh_df.head(10)
# Out:
#                                 Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland             Western Europe               1            7.587
# Iceland                 Western Europe               2            7.561
# Denmark                 Western Europe               3            7.527
# Norway                  Western Europe               4            7.522
# Canada                   North America               5            7.427
# Finland                 Western Europe               6            7.406
# Netherlands             Western Europe               7            7.378
# Sweden                  Western Europe               8            7.364
# New Zealand  Australia and New Zealand               9            7.286
# Australia    Australia and New Zealand              10            7.284
#
#              Standard Error  Economy (GDP per Capita)   Family  \
# Country
# Switzerland         0.03411                   1.39651  1.34951
# ...

# %%
Wh_df.describe(include='all')
# Out:
#             Country              Region  Happiness Rank  Happiness Score  \
# count           158                 158      158.000000       158.000000
# unique          158                  10             NaN              NaN
# top     Switzerland  Sub-Saharan Africa             NaN              NaN
# freq              1                  40             NaN              NaN
# mean            NaN                 NaN       79.493671         5.375734
# std             NaN                 NaN       45.754363         1.145010
# min             NaN                 NaN        1.000000         2.839000
# 25%             NaN                 NaN       40.250000         4.526000
# 50%             NaN                 NaN       79.500000         5.232500
# 75%             NaN                 NaN      118.750000         6.243750
# max             NaN                 NaN      158.000000         7.587000
#
#         Standard Error  Economy (GDP per Capita)      Family  \
# ...

# %% [markdown]
# here from the above statistical summary we observed that in the happiness rank there is max jump from third quartile to upper fence so might be outliers are present

# %%
new_df.info
# Out:
# <bound method DataFrame.info of                                       Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland                   Western Europe               1            7.587
# Iceland                       Western Europe               2            7.561
# Denmark                       Western Europe               3            7.527
# Norway                        Western Europe               4            7.522
# Canada                         North America               5            7.427
# ...                                      ...             ...              ...
# Rwanda                    Sub-Saharan Africa             154            3.465
# Benin                     Sub-Saharan Africa             155            3.340
# Syria        Middle East and Northern Africa             156            3.006
# Burundi                   Sub-Saharan Africa             157            2.905
# ...

# %%
for i in Wh_df.columns:
    print(Wh_df[i].value_counts())
# Out:
# Country
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: count, Length: 158, dtype: int64
# Region
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64
# Happiness Rank
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: count, Length: 157, dtype: int64
# Happiness Score
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# ...

# %%
#here i am checking the frequency of each feature using value_counts
# In region feature value counts gives you the information that in ecah region how many countries are there

# %%
sns.heatmap(Wh_df.isnull())
# Out:
# <Axes: >

# %%
    Wh_df.loc[:,'Region']
# Out:
# Country
# Switzerland                     Western Europe
# Iceland                         Western Europe
# Denmark                         Western Europe
# Norway                          Western Europe
# Canada                           North America
#                             ...
# Rwanda                      Sub-Saharan Africa
# Benin                       Sub-Saharan Africa
# Syria          Middle East and Northern Africa
# Burundi                     Sub-Saharan Africa
# Togo                        Sub-Saharan Africa
# Name: Region, Length: 158, dtype: object

# %%
#here i am displaying no of unique value in each region as a dataframe
Wh_df.nunique().to_frame()
# Out:
#                                  0
# Country                        158
# Region                          10
# Happiness Rank                 157
# Happiness Score                157
# Standard Error                 153
# Economy (GDP per Capita)       158
# Family                         158
# Health (Life Expectancy)       157
# Freedom                        158
# Trust (Government Corruption)  157
# Generosity                     158
# Dystopia Residual              158

# %%
plt.figure(figsize=(10,6))
Wh_df.groupby('Region').apply(lambda x:x.sort_values('Happiness Rank',ascending=False).count()).plot(kind='bar')
plt.xlabel('region')
plt.ylabel('Country count in each region')
# Out:
# Text(0, 0.5, 'Country count in each region')

# %%
Wh_df.groupby(['Region'])['Economy (GDP per Capita)'].mean().plot(kind='bar',color='green')
# Out:
# <Axes: xlabel='Region'>

# %%
here from the above bar graph observation the mean of all the GDP per capita income of all country inside North America region is high

# %%
Wh_df.groupby(['Region'])['Trust (Government Corruption)'].count().plot(kind='bar',color='green')
# Out:
# <Axes: xlabel='Region'>

# %%
#here from the above obseravtion it is clear that the region sub-saharan africa has more no of countries that has corruption

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=Wh_df,style=True)
# Out:
# <Axes: xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %% [markdown]
# here from the above graph of scatterplot it is clear that Happiness score have direct postive relation with Economy as the Economy or GDP rate of any country increases also Happiness score increases

# %%
sns.scatterplot(x='Family',y='Happiness Score',hue='Region',data=Wh_df,style=True)
# Out:
# <Axes: xlabel='Family', ylabel='Happiness Score'>

# %% [markdown]
# here from the above graph of scatterplot it is clear that Happiness score have direct postive relation with Family  as the family support or social support for any country increases also Happiness score increases

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=Wh_df,style=True)
# Out:
# <Axes: xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
plt.figure(figsize=(20,20))
sns.scatterplot(x='Region',y='Happiness Score',data=Wh_df)
# Out:
# <Axes: xlabel='Region', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=Wh_df)
# Out:
# <Axes: xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
here from the above visualization it is clear that

# %%
sns.scatterplot(x='Freedom',y='Happiness Score',data=Wh_df)
# Out:
# <Axes: xlabel='Freedom', ylabel='Happiness Score'>

# %% [markdown]
# Here from above scatterplot visualization that freedom also positively impact on the happiness as the people of any country have the freedom  to enjoy their life then also the happiness score increases.

# %%
# perforing data visualization to check the distribution of data in each feature

# %%
sns.displot(data=Wh_df,x='Economy (GDP per Capita)')

# %% [markdown]
#  here from the above distibution plot it is clear that GDP per Capita(Economy) between 1.00 and 1.25 has highest no  of  frequency counts.

# %%
sns.displot(data=Wh_df,x='Family',kde=True)

# %% [markdown]
# Here from the above plot it is clear that family score between 0.9 to 1.0 and between 1.2 to 1.3 have maximum frequency count in the dataset and actually family score measure how much support will be get from their family and from social envroment when problem solving challeges arrives.during covid 19 also there were a lot of support an individual got from their family and friends when they are facing such  a tough situation in that time.

# %%
sns.displot(data=Wh_df,x='Trust (Government Corruption)',hue='Region')

# %% [markdown]
# Here from the above visualization it is clear that Sub Saharan Africa and central and eatern europe region has very high corruption count  and less happiness score among other rigion

# %%
sns.pairplot(Wh_df)

# %%
#here from the above pair plot we are checking the correlation among the features in the dataset

# %%
correlation=Wh_df.corr()

# %%
# checking correlation between independent feature and target feature using Heat Map
plt.figure(figsize=(10,10))
sns.heatmap(correlation,annot=True,cmap='viridis',fmt='.2f')
# Out:
# <Axes: >

# %%
Wh_df.drop(['Standard Error'],axis=1,inplace=True)

# %%
plt.figure(figsize=(10,6),facecolor='white')
counter=1
for i in Wh_df.columns:
    ax=plt.subplot(4,4,counter)
    sns.distplot(Wh_df[i],color='m')
    plt.xlabel(i,fontsize=12)
    counter+=1
plt.tight_layout()

# %%
Wh_df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# here from the above result that the feature with negative skewed value will have long tail towwards the left of the distribution and postively skewed data have long tail to the right of the distribution .from the above observation data in negligible skwed in the distibution

# %%
Wh_df['Generosity']=np.cbrt(Wh_df['Generosity'])

# %%
Wh_df['Standard Error']=np.cbrt(Wh_df['Standard Error'])

# %%
Wh_df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.979748
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                      -0.961079
# Dystopia Residual               -0.238911
# dtype: float64

# %%
Wh_df
# Out:
#      Country  Region  Happiness Score  Economy (GDP per Capita)   Family  \
# 0        135       9            7.587                   1.39651  1.34951
# 1         58       9            7.561                   1.30232  1.40223
# 2         37       9            7.527                   1.32548  1.36058
# 3        105       9            7.522                   1.45900  1.33095
# 4         24       5            7.427                   1.32629  1.32261
# ..       ...     ...              ...                       ...      ...
# 153      118       8            3.465                   0.22208  0.77370
# 154       13       8            3.340                   0.28665  0.35386
# 155      136       4            3.006                   0.66320  0.47489
# 156       21       8            2.905                   0.01530  0.41587
# 157      141       8            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
Wh_df.plot(kind='box',subplots=True,layout=(6,6),figsize=(10,10))
# Out:
# Country                              Axes(0.125,0.77;0.110714x0.11)
# Region                            Axes(0.257857,0.77;0.110714x0.11)
# Happiness Rank                    Axes(0.390714,0.77;0.110714x0.11)
# Happiness Score                   Axes(0.523571,0.77;0.110714x0.11)
# Economy (GDP per Capita)          Axes(0.656429,0.77;0.110714x0.11)
# Family                            Axes(0.789286,0.77;0.110714x0.11)
# Health (Life Expectancy)            Axes(0.125,0.638;0.110714x0.11)
# Freedom                          Axes(0.257857,0.638;0.110714x0.11)
# Trust (Government Corruption)    Axes(0.390714,0.638;0.110714x0.11)
# Generosity                       Axes(0.523571,0.638;0.110714x0.11)
# Dystopia Residual                Axes(0.656429,0.638;0.110714x0.11)
# dtype: object

# %%
Q1=Wh_df['Trust (Government Corruption)'].quantile(0.25)
Q2=Wh_df['Trust (Government Corruption)'].quantile(0.5)
Q3=Wh_df['Trust (Government Corruption)'].quantile(0.75)
iqr=Q3-Q1
lowfence=Q1-1.5*iqr
uppfence=Q3+1.5*iqr
print(lowfence)
print(uppfence)
# Out:
# -0.11619499999999996
# 0.35812499999999997

# %%
from feature_engine.outliers import ArbitraryOutlierCapper
arb=ArbitraryOutlierCapper(min_capping_dict={'Trust (Government Corruption)':-0.11619499999999996},max_capping_dict={'Trust (Government Corruption)':0.35812499999999997})
Wh_df[['Trust (Government Corruption)']]=arb.fit_transform(Wh_df[['Trust (Government Corruption)']])
plt.boxplot(Wh_df['Trust (Government Corruption)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a8abba9f90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a8abbab390>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a8abba9850>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a8abbb0450>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a8abbb0c90>],
#  'means': []}

# %% [markdown]
# now after removing outlier again we are checking from the boxplot that outlier has been removed or not so it is clear that outlier has been removed

# %%
Q1=Wh_df['Family'].quantile(0.25)
Q2=Wh_df['Family'].quantile(0.5)
Q3=Wh_df['Family'].quantile(0.75)
iqr=Q3-Q1
lowfence=Q1-1.5*iqr
uppfence=Q3+1.5*iqr
print(lowfence)
print(uppfence)
# Out:
# 0.32044875000000017
# 1.7507787499999998

# %%
from feature_engine.outliers import ArbitraryOutlierCapper
arb=ArbitraryOutlierCapper(min_capping_dict={'Family':0.32044875000000017},max_capping_dict={'Family':1.7507787499999998})
Wh_df[['Family']]=arb.fit_transform(Wh_df[['Family']])
plt.boxplot(Wh_df['Family'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a8ad3345d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a8ad335710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a8ad327d10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a8ad336890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a8ad3370d0>],
#  'means': []}

# %%
Wh_df.dtypes
# Out:
# Country                            int32
# Region                             int32
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
Wh_df
# Out:
#              Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland       9               1            7.587
# Iceland           9               2            7.561
# Denmark           9               3            7.527
# Norway            9               4            7.522
# Canada            5               5            7.427
# ...             ...             ...              ...
# Rwanda            8             154            3.465
# Benin             8             155            3.340
# Syria             4             156            3.006
# Burundi           8             157            2.905
# Togo              8             158            2.839
#
#              Economy (GDP per Capita)    Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.349510                   0.94143
# Iceland                       1.30232  1.402230                   0.94784
# Denmark                       1.32548  1.360580                   0.87464
# ...

# %% [markdown]
# here i dropped Happiness rank feature as it is highely negatively correlated with other feature

# %%
x=Wh_df.drop(['Happiness Score'],axis=1)

# %%
y=Wh_df.loc[:,'Happiness Score']

# %%
x
# Out:
#      Country  Region  Happiness Rank  Economy (GDP per Capita)   Family  \
# 0        135       9               1                   1.39651  1.34951
# 1         58       9               2                   1.30232  1.40223
# 2         37       9               3                   1.32548  1.36058
# 3        105       9               4                   1.45900  1.33095
# 4         24       5               5                   1.32629  1.32261
# ..       ...     ...             ...                       ...      ...
# 153      118       8             154                   0.22208  0.77370
# 154       13       8             155                   0.28665  0.35386
# 155      136       4             156                   0.66320  0.47489
# 156       21       8             157                   0.01530  0.41587
# 157      141       8             158                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %% [markdown]
#                                     DATA PREPROCESSING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# tranforming categorical feature into numerical form as the model will work only with numerical value
lbl=LabelEncoder()
Wh_df['Country']=lbl.fit_transform(Wh_df['Country']).reshape(-1,1)

# %%
Wh_df['Region']=lbl.fit_transform(Wh_df['Region']).reshape(-1,1)

# %%
Wh_df
# Out:
#              Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland       9               1            7.587
# Iceland           9               2            7.561
# Denmark           9               3            7.527
# Norway            9               4            7.522
# Canada            5               5            7.427
# ...             ...             ...              ...
# Rwanda            8             154            3.465
# Benin             8             155            3.340
# Syria             4             156            3.006
# Burundi           8             157            2.905
# Togo              8             158            2.839
#
#              Economy (GDP per Capita)    Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.349510                   0.94143
# Iceland                       1.30232  1.402230                   0.94784
# Denmark                       1.32548  1.360580                   0.87464
# ...

# %%
Wh_df.tail(30)
# Out:
#                           Region  Happiness Rank  Happiness Score  \
# Country
# Myanmar                        6             129            4.307
# Georgia                        1             130            4.297
# Malawi                         8             131            4.292
# Sri Lanka                      7             132            4.271
# Cameroon                       8             133            4.252
# Bulgaria                       1             134            4.218
# Egypt                          4             135            4.194
# Yemen                          4             136            4.077
# Angola                         8             137            4.033
# Mali                           8             138            3.995
# Congo (Brazzaville)            8             139            3.989
# Comoros                        8             140            3.956
# Uganda                         8             141            3.931
# ...

# %%
correlation['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind='bar')
plt.xlabel('Independent Feature')
plt.xlabel('Independent Feature')
plt.ylabel('target feature')
plt.title('correlationship between independent feature and target feature')
# Out:
# Text(0.5, 1.0, 'correlationship between independent feature and target feature')

# %% [markdown]
# here from the above barplot between indepenent feature and target feature the esential feature that is positively correlated with target feature are:
# 1.Economy
# 2.Family
# 3.Health
# 4.Freedom
# 5.Dystopia residual
# 6. corruption
# 7. country

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled_data_x=StandardScaler()

# %%
x=pd.DataFrame(scaled_data_x.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#       Country    Region  Happiness Rank  Economy (GDP per Capita)    Family  \
# 0    1.238770  1.300256       -1.721000                  1.369621  1.320281
# 1   -0.449465  1.300256       -1.699075                  1.135226  1.514458
# 2   -0.909893  1.300256       -1.677149                  1.192861  1.361054
# 3    0.581016  1.300256       -1.655224                  1.525130  1.251922
# 4   -1.194920 -0.040302       -1.633299                  1.194876  1.221204
# ..        ...       ...             ...                       ...       ...
# 153  0.866043  0.965117        1.633576                 -1.552987 -0.800520
# 154 -1.436096  0.965117        1.655501                 -1.392303 -2.346860
# 155  1.260695 -0.375441        1.677427                 -0.455245 -1.901086
# 156 -1.260695  0.965117        1.699352                 -2.067566 -2.118467
# 157  1.370321  0.965117        1.721277                 -1.586334 -3.134725
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

y = y.values.reshape(-1, 1)  
scaler = StandardScaler()
y_standardized = scaler.fit_transform(y)

# %%
x.drop('Trust (Government Corruption)',axis=1,inplace=True)

# %%
x
# Out:
#        Region  Happiness Rank  Economy (GDP per Capita)    Family  \
# 0    1.300256       -1.721000                  1.369621  1.357628
# 1    1.300256       -1.699075                  1.135226  1.559142
# 2    1.300256       -1.677149                  1.192861  1.399941
# 3    1.300256       -1.655224                  1.525130  1.286685
# 4   -0.040302       -1.633299                  1.194876  1.254807
# ..        ...             ...                       ...       ...
# 153  0.965117        1.633576                 -1.552987 -0.843316
# 154  0.965117        1.655501                 -1.392303 -2.448088
# 155 -0.375441        1.677427                 -0.455245 -1.985470
# 156  0.965117        1.699352                 -2.067566 -2.211065
# 157  0.965117        1.721277                 -1.586334 -2.575797
#
#      Health (Life Expectancy)   Freedom  Dystopia Residual
# 0                    1.263408  1.577438           0.758258
# ...

# %%
y=y_standardized

# %%
y
# Out:
# array([[ 1.93736005],
#        [ 1.91458063],
#        [ 1.88479215],
#        [ 1.88041149],
#        [ 1.79717898],
#        [ 1.77878022],
#        [ 1.75424853],
#        [ 1.74198268],
#        [ 1.67364441],
#        [ 1.67189215],
#        [ 1.66663536],
#        [ 1.62107651],
#        [ 1.59829709],
#        [ 1.58690738],
#        [ 1.52733042],
#        [ 1.40817651],
#        [ 1.37575964],
#        [ 1.37050285],
#        [ 1.36787446],
#        [ 1.33633371],
#        [ 1.30654524],
#        [ 1.29427939],
#        [ 1.25660573],
#        [ 1.24609215],
#        [ 1.23557857],
#        [ 1.20403783],
#        [ 1.1339473 ],
#        [ 1.08225553],
#        [ 1.05071479],
#        [ 1.04983865],
#        [ 0.98938557],
#        [ 0.97186293],
#        [ 0.96485388],
#        [ 0.94557898],
#        [ 0.90702919],
#        [ 0.83518639],
#        [ 0.81153084],
#        [ 0.80802631],
#        [ 0.80539791],
#        [ 0.78261849],
#        [ 0.69412919],
# ...

# %%
y.shape
# Out:
# (158,)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['values']=[variance_inflation_factor(x.values,i) for i in range (len(x.columns))]

# %%
vif['features']=x.columns

# %%
vif
# Out:
#       values                       features
# 0   1.083801                        Country
# 1  70.815479                 Happiness Rank
# 2  12.753694       Economy (GDP per Capita)
# 3   5.374256                         Family
# 4   7.423535       Health (Life Expectancy)
# 5   3.101847                        Freedom
# 6   1.866947  Trust (Government Corruption)
# 7   1.866255                     Generosity
# 8  16.847646              Dystopia Residual

# %% [markdown]
# here i have already removed Happiness Rank becuase it had  high variance inflation factor of 72 after removing the that feature vif for other feature are in their  acceptable range of -5 to +5

# %%
x.drop(['Generosity'],axis=1,inplace=True)

# %%
x.drop(['Dystopia Residual'],axis=1,inplace=True)

# %%
x.drop('Region',axis=1,inplace=True)

# %%
vif
# Out:
#       values                       features
# 0   1.084154                        Country
# 1   1.435634                         Region
# 2  74.107444                 Happiness Rank
# 3  13.417840       Economy (GDP per Capita)
# 4   5.473520                         Family
# 5   7.465238       Health (Life Expectancy)
# 6   3.235843                        Freedom
# 7   1.965592  Trust (Government Corruption)
# 8   2.094740                     Generosity
# 9  17.538190              Dystopia Residual

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor,ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
mxac=0
mxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>mxac:
        mxac=acc
        mxrs=i
print('maximum r2 score is',mxac,'at random state',mxrs)
# Out:
# maximum r2 score is 0.9998832883182804 at random state 7

# %%
en=ElasticNet()
en.fit(x_train,y_train)
rdpred_test=en.predict(x_test)
rdpred_train=en.predict(x_train)
print('R2_score',r2_score(y_test,rdpred_test)*100)
print('R2 score on training data',r2_score(y_train,rdpred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,rdpred_test))
print('Mean Squared  Error',mean_squared_error(y_test,rdpred_test))
print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,rdpred_test)))
print('cross validation score',cross_val_score(en,x,y,cv=5,scoring='r2').mean()*100)
# Out:
# R2_score 65.43289865029351
# R2 score on training data 66.24082838875543
# Mean Absolute Error 0.4694836503591553
# Mean Squared  Error 0.3459511689012542
# Root Mean Absolute Error 0.5881761376503252
# cross validation score -1093.1631507825218

# %%
rfr=RandomForestRegressor()

rfr.fit(x_train,y_train)
rfrpred_test=rfr.predict(x_test)
rfrpred_train=rfr.predict(x_train)
print('R2_score',r2_score(y_test,rfrpred_test)*100)
print('R2 score on training data',r2_score(y_train,rfrpred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,rfrpred_test))
print('Mean Squared  Error',mean_squared_error(y_test,rfrpred_test))
print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,rfrpred_test)))
print('cross validation score',cross_val_score(rfr,x,y,cv=5,scoring='r2').mean()*100)
# Out:
# R2_score 99.5666147466831
# R2 score on training data 99.9512870152316
# Mean Absolute Error 0.0343324999999994
# Mean Squared  Error 0.004337364983333211
# Root Mean Absolute Error 0.06585867432110375
# cross validation score -162.55967164862196

# %%
score1=cross_val_score(lr,x,y,cv=5)
print(score1)
print(score1.mean())
print('difference between r2 score and cross validation score is ',r2_score(y_test,pred)-score1.mean())
# Out:
# [0.98063883 0.99452144 0.99640903 0.995877   0.99383103]
# 0.9922554667046534
# difference between r2 score and cross validation score is  0.0051315970607008765

# %%
score2=cross_val_score(en,x,y,cv=5)
print(score2)
print(score2.mean())
print('difference between r2 score and cross validation score is ',(r2_score(y_test,rdpred_test)-score2.mean())*100)
# Out:
# [-30.16242323  -2.12041063   0.4137171   -7.14877394 -15.64026684]
# -10.931631507825218
# difference between r2 score and cross validation score is  1158.5960494328153

# %%
score3=cross_val_score(rfr,x,y,cv=5)
print(score3)
print(score3.mean())
print('difference between r2 score and cross validation score is ',(r2_score(y_test,rfrpred_test)-score3.mean())*100)
# Out:
# [-3.69784635 -0.64967585 -0.45470424 -1.03910701 -2.24116197]
# -1.6164990836082325
# difference between r2 score and cross validation score is  261.21652310750636

# %%
gbrscore=cross_val_score(gbr,x,y,cv=5)
print(gbrscore)
print(gbrscore.mean())
print('difference between r2 score and cross validation score is ',(r2_score(y_test,gbrpred_test)-gbrscore.mean())*100)
# Out:
# [-2.96318623 -0.29633058 -0.29190094 -0.37643767 -1.89855615]
# -1.165282314663185
# difference between r2 score and cross validation score is  216.30668119065635

# %%
knn=KNeighborsRegressor()

knn.fit(x_train,y_train)
knnpred_test=knn.predict(x_test)
knnpred_train=knn.predict(x_train)
print('R2_score',r2_score(y_test,knnpred_test)*100)
print('R2 score on training data',r2_score(y_train,knnpred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,knnpred_test))
print('Mean Squared  Error',mean_squared_error(y_test,knnpred_test))
print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,knnpred_test)))
print('cross validation score',cross_val_score(knn,x,y,cv=5,scoring='r2').mean()*100)
# Out:
# R2_score 92.86279068781855
# R2 score on training data 93.99472857432556
# Mean Absolute Error 0.23480329143601425
# Mean Squared  Error 0.0777272470825372
# Root Mean Absolute Error 0.2787960671934545
# cross validation score -412.4488522250499

# %%
svr=SVR()
svr.fit(x_train,y_train)
svrpred_test=svr.predict(x_test)
svrpred_train=svr.predict(x_train)
print('R2_score',r2_score(y_test,svrpred_test)*100)
print('R2 score on training data',r2_score(y_train,svrpred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,svrpred_test))
print('Mean Squared  Error',mean_squared_error(y_test,svrpred_test))
print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,svrpred_test)))
print('cross validation score',cross_val_score(svr,x,y,cv=5,scoring='r2').mean()*100)
# Out:
# R2_score 96.03070534772185
# R2 score on training data 98.90307868285227
# Mean Absolute Error 0.14246830551438208
# Mean Squared  Error 0.043227308137712445
# Root Mean Absolute Error 0.20791177969925717
# cross validation score -332.33604279178707

# %%
svrscore=cross_val_score(svr,x,y,cv=5)
print(svrscore)
print(svrscore.mean())
print('difference between r2 score and cross validation score is ',(r2_score(y_test,svrpred_test)-svrscore.mean())*100)
# Out:
# [-10.53332977   0.25781286   0.90278994   0.04993099  -7.29400616]
# -3.3233604279178706
# difference between r2 score and cross validation score is  428.36674813950884

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
gbrpred_test=gbr.predict(x_test)
gbrpred_train=gbr.predict(x_train)
print('R2_score',r2_score(y_test,gbrpred_test))
print('R2 score on training data',r2_score(y_train,gbrpred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,gbrpred_test))
print('Mean Squared  Error',mean_squared_error(y_test,gbrpred_test))
print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,gbrpred_test)))
print('cross validation score',cross_val_score(gbr,x,y,cv=5,scoring='r2').mean()*100)
# Out:
# R2_score 0.9971230109439035
# R2 score on training data 99.99977625130565
# Mean Absolute Error 0.03188041355002431
# Mean Squared  Error 0.0031331635298309586
# Root Mean Absolute Error 0.055974668644226545
# cross validation score -115.99944662997359

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV

# Define the model
model = LinearRegression()

# Define the parameters to search over
param_grid = {
    'fit_intercept': [True, False],
    # 'normalize': [True, False], # Deprecated
    'n_jobs': [-1, 1]
}

# Set up the grid search with cross-validation
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='r2')

# Fit the grid search to the data
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'fit_intercept': [True, False], 'n_jobs': [-1, 1]},
#              scoring='r2')

# %%
grid_search.best_params_
# Out:
# {'fit_intercept': False, 'n_jobs': -1}

# %%
final_model=LinearRegression(fit_intercept=False,n_jobs=-1)
#final_model=RandomForestClassifier(criterion='Entropy',max_depth=50,n_estimators=500,n_jobs=-3,random_state=100)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
accuracy=r2_score(y_test,pred)
score=cross_val_score(final_model,y_test,pred)
print(score.mean()*100)
print(accuracy*100)
print('differnce between r2_score and cross_val score ',accuracy-score.mean())
# Out:
# 99.97316111639952
# 99.98107842211921
# differnce between r2_score and cross_val score  7.917305719684631e-05

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2]
}

model = GradientBoostingRegressor()
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [50, 100, 200]},
#              scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}

# %%
final_model1=GradientBoostingRegressor(learning_rate=0.1,max_depth=3,n_estimators=200)
#final_model=RandomForestClassifier(criterion='Entropy',max_depth=50,n_estimators=500,n_jobs=-3,random_state=100)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
accuracy=r2_score(y_test,pred)
score=cross_val_score(final_model1,y_test,pred)
print(score.mean()*100)
print(accuracy*100)
print('differnce between r2_score and cross_val score ',accuracy-score.mean())
# Out:
# 97.44817528434245
# 99.98107842211921
# differnce between r2_score and cross_val score  0.02532903137776754

# %%
final_model3=Ridge(alpha=10,fit_intercept=False,solver='sparse_cg')
#final_model3=Ridge()
#final_model=RandomForestClassifier(criterion='Entropy',max_depth=50,n_estimators=500,n_jobs=-3,random_state=100)
final_model3.fit(x_train,y_train)
pred=final_model3.predict(x_test)
accuracy=r2_score(y_test,pred)
scorerd=cross_val_score(final_model3,y_test,pred)
print(scorerd.mean()*100)
print(accuracy*100)
print('differnce between r2_score and cross_val score ',accuracy-scorerd.mean())
# Out:
# 90.29422085919671
# 99.73870637653542
# differnce between r2_score and cross_val score  0.09444485517338708

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

gb_regressor = GradientBoostingRegressor()

# Fit the model with the training data
gb_regressor.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2]
}

model = GradientBoostingRegressor()
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [50, 100, 200]},
#              scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 50}

# %%
final_model1=GradientBoostingRegressor(learning_rate=0.1,max_depth=3,n_estimators=50)
#final_model=RandomForestClassifier(criterion='Entropy',max_depth=50,n_estimators=500,n_jobs=-3,random_state=100)
final_model1.fit(x_train,y_train)
pred=final_model1.predict(x_test)
accuracy=r2_score(y_test,pred)
score=cross_val_score(final_model1,y_test,pred)
print(score.mean()*100)
print(accuracy*100)
print('differnce between r2_score and cross_val score ',accuracy-score.mean())
# Out:
# 97.86275161748048
# 99.61659170169676
# differnce between r2_score and cross_val score  0.01753840084216285

# %% [markdown]
# # here i havechoosen GradientBoostingRegressor for this Project as my final model

# %%
import joblib
joblib.dump(final_model1,'world_happiness_proj.pkl')
# Out:
# ['world_happiness_proj.pkl']

# %%
predictions=final_model1.predict(x_test)
predictions
# Out:
# array([-0.90898955,  0.54156602, -1.02151015, -1.94280892, -0.26282619,
#         1.04129337, -0.42859317, -0.42786892, -0.36287723, -1.4463194 ,
#         1.30019747,  0.39335822,  1.52272238,  0.09163747,  1.24049734,
#         1.04129337, -0.75077452, -0.58406823, -0.32651509,  0.29180841,
#        -1.49790656,  1.36413887,  1.61136132,  1.66614034,  0.95819424,
#        -0.16145607,  0.44769382, -1.21112625, -0.89909504, -1.48009825,
#        -1.55378703, -0.07856784])

# %%
dummy_test=np.array(y_test)

# %%
df=pd.DataFrame()
df['predicted']=predictions
df['orignal']=dummy_test
df
# Out:
#     predicted   orignal
# 0   -0.908990 -0.936352
# 1    0.541566  0.535549
# 2   -1.021510 -1.035355
# 3   -1.942809 -2.164688
# 4   -0.262826 -0.279253
# 5    1.041293  1.049839
# 6   -0.428593 -0.418558
# 7   -0.427869 -0.437833
# 8   -0.362877 -0.373875
# 9   -1.446319 -1.265777
# 10   1.300197  1.336334
# 11   0.393358  0.396244
# 12   1.522722  1.408177
# 13   0.091637  0.150928
# 14   1.240497  1.235579
# 15   1.041293  0.989386
# 16  -0.750775 -0.761126
# 17  -0.584068 -0.604298
# 18  -0.326515 -0.354600
# 19   0.291808  0.279719
# 20  -1.497907 -1.507590
# 21   1.364139  1.367874
# 22   1.611361  1.598297
# 23   1.666140  1.671892
# 24   0.958194  0.971863
# 25  -0.161456 -0.160975
# 26   0.447694  0.449688
# 27  -1.211126 -1.243874
# 28  -0.899095 -0.882032
# 29  -1.480098 -1.484810
# 30  -1.553787 -1.397197
# 31  -0.078568 -0.038317
